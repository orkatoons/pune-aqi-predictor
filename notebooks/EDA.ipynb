# %% [markdown]
# # Exploratory Data Analysis
#
# We will be working with our processed csv file to understand the features and trends of the existing data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../data/processed/processed.csv")

# %% [markdown]
# ### Exploring the dataset and checking for missing values

# %%
data
# Out:
#             Date    AQI  Year  Month  Day  temperature_2m_max  \
# 0     2018-01-01   75.0  2018      1    1              28.253
# 1     2018-01-02   76.0  2018      1    2              28.453
# 2     2018-01-03   79.0  2018      1    3              28.903
# 3     2018-01-04   84.0  2018      1    4              28.353
# 4     2018-01-05   97.0  2018      1    5              28.453
# ...          ...    ...   ...    ...  ...                 ...
# 2552  2024-12-27  109.0  2024     12   27              30.253
# 2553  2024-12-28   95.0  2024     12   28              30.103
# 2554  2024-12-29  110.0  2024     12   29              31.003
# 2555  2024-12-30   87.0  2024     12   30              31.053
# 2556  2024-12-31  103.0  2024     12   31              30.653
#
#       temperature_2m_min  precipitation_sum  weather_code  sunshine_duration  \
# 0                 14.503                0.0           0.0          36062.707
# ...

# %%
data.head()
# Out:
#          Date   AQI  Year  Month  Day  temperature_2m_max  temperature_2m_min  \
# 0  2018-01-01  75.0  2018      1    1              28.253              14.503
# 1  2018-01-02  76.0  2018      1    2              28.453              12.903
# 2  2018-01-03  79.0  2018      1    3              28.903              15.303
# 3  2018-01-04  84.0  2018      1    4              28.353              15.303
# 4  2018-01-05  97.0  2018      1    5              28.453              14.003
#
#    precipitation_sum  weather_code  sunshine_duration  cloud_cover_mean  \
# 0                0.0           0.0          36062.707          0.000000
# 1                0.0           1.0          36040.188          7.166666
# 2                0.0           0.0          36101.605          0.083333
# 3                0.0           0.0          36083.652          1.541667
# 4                0.0           3.0          36066.500         46.125000
#
#    wind_speed_10m_mean  winddirection_10m_dominant
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2557 entries, 0 to 2556
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        2557 non-null   object
#  1   AQI                         2557 non-null   float64
#  2   Year                        2557 non-null   int64
#  3   Month                       2557 non-null   int64
#  4   Day                         2557 non-null   int64
#  5   temperature_2m_max          2557 non-null   float64
#  6   temperature_2m_min          2557 non-null   float64
#  7   precipitation_sum           2557 non-null   float64
#  8   weather_code                2557 non-null   float64
#  9   sunshine_duration           2557 non-null   float64
#  10  cloud_cover_mean            2557 non-null   float64
#  11  wind_speed_10m_mean         2557 non-null   float64
#  12  winddirection_10m_dominant  2557 non-null   float64
# ...

# %%
data.describe()
# Out:
#                AQI         Year        Month          Day  temperature_2m_max  \
# count  2557.000000  2557.000000  2557.000000  2557.000000         2557.000000
# mean    101.420023  2021.000782     6.522487    15.730935           30.926309
# std      44.761035     2.000587     3.449499     8.802361            4.031822
# min      19.000000  2018.000000     1.000000     1.000000           20.203000
# 25%      66.000000  2019.000000     4.000000     8.000000           28.003000
# 50%      92.000000  2021.000000     7.000000    16.000000           29.903000
# 75%     127.000000  2023.000000    10.000000    23.000000           33.903000
# max     435.000000  2024.000000    12.000000    31.000000           42.953000
#
#        temperature_2m_min  precipitation_sum  weather_code  sunshine_duration  \
# count         2557.000000        2557.000000   2557.000000        2557.000000
# mean            20.241150           3.078256     27.255768       34192.954981
# ...

# %%
data.isna().sum()
# Out:
# Date                          0
# AQI                           0
# Year                          0
# Month                         0
# Day                           0
# temperature_2m_max            0
# temperature_2m_min            0
# precipitation_sum             0
# weather_code                  0
# sunshine_duration             0
# cloud_cover_mean              0
# wind_speed_10m_mean           0
# winddirection_10m_dominant    0
# dtype: int64

# %% [markdown]
# ## Creating Plots

# %%
# Scatter plot

fig, ax = plt.subplots()
ax.scatter(x = data["Date"][:1000], # visualise the first 1000 values
           y= data["AQI"][:1000])
ax.set_xlabel("Date")
ax.set_ylabel("AQI")
ax.set_title("First 1000 datapoints plotted")
plt.show()

# %%
# Histogram
data.AQI.plot.hist(xlabel="AQI")
# Out:
# <Axes: xlabel='AQI', ylabel='Frequency'>

# %% [markdown]
# #### Inference
# We can see the most common AQI levels are in the 90-100 range, signifying reasonable AQI Metrics

# %%
# Plotting the Yearly median AQI level

data.groupby(["Year"])["AQI"].median().plot()
plt.xlabel("Year")
plt.ylabel("Median AQI Level")
plt.show()

# %% [markdown]
# #### Inference
# * 2020 had the lowest aqi levels due to the COVID Lockdown
# * 2023 has seen an extreme increase in pollution levels as companies started enforcing Work from office policies

# %%
# Boxplot to identify outlier data

plt.figure(figsize=(10,6))
sns.boxplot(x="Month", y="AQI", data=data)
plt.title("Distribution of AQI across each Month")
plt.ylabel("AQI")
plt.xlabel("Month")
plt.show()

# %% [markdown]
# #### Inference
# * We can clearly see monsoon months have lower AQI Levels (outliers are also more concentrated)
# * While winter months have higher Levels on an average

# %%
# Creating and plotting correlation matrix

correlation_matrix = data.corr(numeric_only=True)
plt.figure(figsize=(8,5))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="crest")
# Out:
# <Axes: >

# %% [markdown]
# #### Inference
# We will be focusing on high correlation to AQI
# * Minimum temprature has high negative correlation to AQI
# * Weather code also signifies helps identify AQI levels (since a higher weather code signifies more rain and lower AQI Levels)
# * Cloud coverage and wind speed also help identify AQI while wind direction has lower negative correlation
