# %% [markdown]
# # Exploratory Data Analysis
#
# We will be working with our processed csv file to understand the features and trends of the existing data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../data/processed/processed.csv", index_col="Date")

# %% [markdown]
# ### Exploring the dataset and checking for missing values

# %%
data
# Out:
#               AQI  Year  Month  Day  temperature_2m_max  temperature_2m_min  \
# Date
# 2018-01-01   75.0  2018      1    1              28.253              14.503
# 2018-01-02   76.0  2018      1    2              28.453              12.903
# 2018-01-03   79.0  2018      1    3              28.903              15.303
# 2018-01-04   84.0  2018      1    4              28.353              15.303
# 2018-01-05   97.0  2018      1    5              28.453              14.003
# ...           ...   ...    ...  ...                 ...                 ...
# 2024-12-27  109.0  2024     12   27              30.253              20.053
# 2024-12-28   95.0  2024     12   28              30.103              19.503
# 2024-12-29  110.0  2024     12   29              31.003              19.603
# 2024-12-30   87.0  2024     12   30              31.053              19.803
# 2024-12-31  103.0  2024     12   31              30.653              18.903
#
# ...

# %%
data.head()
# Out:
#              AQI  Year  Month  Day  temperature_2m_max  temperature_2m_min  \
# Date
# 2018-01-01  75.0  2018      1    1              28.253              14.503
# 2018-01-02  76.0  2018      1    2              28.453              12.903
# 2018-01-03  79.0  2018      1    3              28.903              15.303
# 2018-01-04  84.0  2018      1    4              28.353              15.303
# 2018-01-05  97.0  2018      1    5              28.453              14.003
#
#             precipitation_sum  weather_code  sunshine_duration  \
# Date
# 2018-01-01                0.0           0.0          36062.707
# 2018-01-02                0.0           1.0          36040.188
# 2018-01-03                0.0           0.0          36101.605
# 2018-01-04                0.0           0.0          36083.652
# 2018-01-05                0.0           3.0          36066.500
#
#             cloud_cover_mean  wind_speed_10m_mean  winddirection_10m_dominant
# Date
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2557 entries, 2018-01-01 to 2024-12-31
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AQI                         2557 non-null   float64
#  1   Year                        2557 non-null   int64
#  2   Month                       2557 non-null   int64
#  3   Day                         2557 non-null   int64
#  4   temperature_2m_max          2557 non-null   float64
#  5   temperature_2m_min          2557 non-null   float64
#  6   precipitation_sum           2557 non-null   float64
#  7   weather_code                2557 non-null   float64
#  8   sunshine_duration           2557 non-null   float64
#  9   cloud_cover_mean            2557 non-null   float64
#  10  wind_speed_10m_mean         2557 non-null   float64
#  11  winddirection_10m_dominant  2557 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 259.7+ KB

# %%
data.describe()
# Out:
#                AQI         Year        Month          Day  temperature_2m_max  \
# count  2557.000000  2557.000000  2557.000000  2557.000000         2557.000000
# mean    101.420023  2021.000782     6.522487    15.730935           30.926309
# std      44.761035     2.000587     3.449499     8.802361            4.031822
# min      19.000000  2018.000000     1.000000     1.000000           20.203000
# 25%      66.000000  2019.000000     4.000000     8.000000           28.003000
# 50%      92.000000  2021.000000     7.000000    16.000000           29.903000
# 75%     127.000000  2023.000000    10.000000    23.000000           33.903000
# max     435.000000  2024.000000    12.000000    31.000000           42.953000
#
#        temperature_2m_min  precipitation_sum  weather_code  sunshine_duration  \
# count         2557.000000        2557.000000   2557.000000        2557.000000
# mean            20.241150           3.078256     27.255768       34192.954981
# ...
