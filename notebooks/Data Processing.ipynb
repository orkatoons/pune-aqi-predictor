# %% [markdown]
# # Processing the Data
#
# The goal is to treat both datasets for missing values with the end goal being to merge both datasets to 1 processed CSV file

# %%
import openmeteo_requests
import pandas as pd
import requests_cache
from retry_requests import retry
import requests
import os
from datetime import datetime
from dotenv import load_dotenv

# %%
aqi_data = pd.read_csv("../data/raw/AQI-Data.csv", parse_dates=["Date"])
weather_data = pd.read_csv("../data/raw/weather-data.csv", parse_dates=["date"])

# %% [markdown]
# ## Reading and parsing AQI data

# %%
aqi_data[:10]
# Out:
#    Unnamed: 0       Date    AQI
# 0           0 2018-01-01   75.0
# 1           1 2018-01-02   76.0
# 2           2 2018-01-03   79.0
# 3           3 2018-01-04   84.0
# 4           4 2018-01-05   97.0
# 5           5 2018-01-06   84.0
# 6           6 2018-01-07   63.0
# 7           7 2018-01-08   65.0
# 8           8 2018-01-09   78.0
# 9           9 2018-01-10  104.0

# %%
len(aqi_data)
# Out:
# 2557

# %%
aqi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2557 entries, 0 to 2556
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2557 non-null   int64
#  1   Date        2557 non-null   datetime64[ns]
#  2   AQI         2303 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 60.1 KB

# %%
aqi_data.describe()
# Out:
#         Unnamed: 0                 Date          AQI
# count  2557.000000                 2557  2303.000000
# mean   1278.000000  2021-07-02 00:00:00   102.771168
# min       0.000000  2018-01-01 00:00:00    19.000000
# 25%     639.000000  2019-10-02 00:00:00    68.000000
# 50%    1278.000000  2021-07-02 00:00:00    94.000000
# 75%    1917.000000  2023-04-02 00:00:00   128.000000
# max    2556.000000  2024-12-31 00:00:00   435.000000
# std     738.286643                  NaN    44.665376

# %%
aqi_data.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AQI           254
# dtype: int64

# %%
aqi_data.dtypes
# Out:
# Unnamed: 0             int64
# Date          datetime64[ns]
# AQI                  float64
# dtype: object

# %% [markdown]
# ## Treating missing values
#
# To treat missing values we will do the following steps
# * 1. Create columns for month and year
#   2. Fill missing AQI values using the median value of the month of the given year

# %%
# Add month and year to each value in the dataframe

aqi_data["Year"] = aqi_data["Date"].dt.year
aqi_data["Month"] = aqi_data["Date"].dt.month

# %%
aqi_data
# Out:
#       Unnamed: 0       Date    AQI  Year  Month
# 0              0 2018-01-01   75.0  2018      1
# 1              1 2018-01-02   76.0  2018      1
# 2              2 2018-01-03   79.0  2018      1
# 3              3 2018-01-04   84.0  2018      1
# 4              4 2018-01-05   97.0  2018      1
# ...          ...        ...    ...   ...    ...
# 2552        2552 2024-12-27  109.0  2024     12
# 2553        2553 2024-12-28   95.0  2024     12
# 2554        2554 2024-12-29  110.0  2024     12
# 2555        2555 2024-12-30   87.0  2024     12
# 2556        2556 2024-12-31  103.0  2024     12
#
# [2557 rows x 5 columns]

# %%
#Using grouping to fill missing values

groups = aqi_data.groupby(["Year", "Month"])
medians = groups["AQI"].transform("median")
aqi_data["AQI"] = aqi_data["AQI"].fillna(medians)

# %%
aqi_data
# Out:
#       Unnamed: 0       Date    AQI  Year  Month
# 0              0 2018-01-01   75.0  2018      1
# 1              1 2018-01-02   76.0  2018      1
# 2              2 2018-01-03   79.0  2018      1
# 3              3 2018-01-04   84.0  2018      1
# 4              4 2018-01-05   97.0  2018      1
# ...          ...        ...    ...   ...    ...
# 2552        2552 2024-12-27  109.0  2024     12
# 2553        2553 2024-12-28   95.0  2024     12
# 2554        2554 2024-12-29  110.0  2024     12
# 2555        2555 2024-12-30   87.0  2024     12
# 2556        2556 2024-12-31  103.0  2024     12
#
# [2557 rows x 5 columns]

# %%
aqi_data.isna().sum()
# Out:
# Unnamed: 0     0
# Date           0
# AQI           31
# Year           0
# Month          0
# dtype: int64

# %%
# Check for data values that are still missing

mask = aqi_data["AQI"].isna()
aqi_data[mask]
# Out:
#       Unnamed: 0       Date  AQI  Year  Month
# 1673        1673 2022-08-01  NaN  2022      8
# 1674        1674 2022-08-02  NaN  2022      8
# 1675        1675 2022-08-03  NaN  2022      8
# 1676        1676 2022-08-04  NaN  2022      8
# 1677        1677 2022-08-05  NaN  2022      8
# 1678        1678 2022-08-06  NaN  2022      8
# 1679        1679 2022-08-07  NaN  2022      8
# 1680        1680 2022-08-08  NaN  2022      8
# 1681        1681 2022-08-09  NaN  2022      8
# 1682        1682 2022-08-10  NaN  2022      8
# 1683        1683 2022-08-11  NaN  2022      8
# 1684        1684 2022-08-12  NaN  2022      8
# 1685        1685 2022-08-13  NaN  2022      8
# 1686        1686 2022-08-14  NaN  2022      8
# 1687        1687 2022-08-15  NaN  2022      8
# 1688        1688 2022-08-16  NaN  2022      8
# 1689        1689 2022-08-17  NaN  2022      8
# 1690        1690 2022-08-18  NaN  2022      8
# 1691        1691 2022-08-19  NaN  2022      8
# 1692        1692 2022-08-20  NaN  2022      8
# 1693        1693 2022-08-21  NaN  2022      8
# 1694        1694 2022-08-22  NaN  2022      8
# 1695        1695 2022-08-23  NaN  2022      8
# 1696        1696 2022-08-24  NaN  2022      8
# 1697        1697 2022-08-25  NaN  2022      8
# 1698        1698 2022-08-26  NaN  2022      8
# 1699        1699 2022-08-27  NaN  2022      8
# 1700        1700 2022-08-28  NaN  2022      8
# 1701        1701 2022-08-29  NaN  2022      8
# 1702        1702 2022-08-30  NaN  2022      8
# 1703        1703 2022-08-31  NaN  2022      8

# %%
# Filling in missing values in august by taking median of values from the respective day in August or other years in the dataset

# Start by adding a day column
aqi_data["Day"] = aqi_data["Date"].dt.day

# %%
aqi_data
# Out:
#       Unnamed: 0       Date    AQI  Year  Month  Day
# 0              0 2018-01-01   75.0  2018      1    1
# 1              1 2018-01-02   76.0  2018      1    2
# 2              2 2018-01-03   79.0  2018      1    3
# 3              3 2018-01-04   84.0  2018      1    4
# 4              4 2018-01-05   97.0  2018      1    5
# ...          ...        ...    ...   ...    ...  ...
# 2552        2552 2024-12-27  109.0  2024     12   27
# 2553        2553 2024-12-28   95.0  2024     12   28
# 2554        2554 2024-12-29  110.0  2024     12   29
# 2555        2555 2024-12-30   87.0  2024     12   30
# 2556        2556 2024-12-31  103.0  2024     12   31
#
# [2557 rows x 6 columns]

# %%
# Computing medians for every day in August
august_medians = (aqi_data[(aqi_data["Month"]==8) & (aqi_data["Year"] != 2022)]
    .groupby("Day")["AQI"]
    .median()
                 )

# %%
august_medians
# Out:
# Day
# 1     72.0
# 2     72.0
# 3     51.5
# 4     54.5
# 5     54.0
# 6     63.0
# 7     59.5
# 8     57.5
# 9     54.5
# 10    58.5
# 11    59.5
# 12    57.0
# 13    59.5
# 14    61.5
# 15    59.0
# 16    65.5
# 17    63.0
# 18    67.0
# 19    66.5
# 20    63.5
# 21    68.0
# 22    62.5
# 23    58.5
# 24    63.5
# 25    61.0
# 26    63.5
# 27    65.0
# 28    61.5
# 29    65.0
# 30    71.0
# 31    62.5
# Name: AQI, dtype: float64

# %%
mask = (aqi_data["Year"] == 2022) & (aqi_data["Month"] == 8) & (aqi_data["AQI"].isna())

# %%
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2552    False
# 2553    False
# 2554    False
# 2555    False
# 2556    False
# Length: 2557, dtype: bool

# %%
aqi_data.loc[mask, "AQI"] = aqi_data.loc[mask, "Day"].map(august_medians)

# %%
aqi_data.isna().sum()
# Out:
# Unnamed: 0    0
# Date          0
# AQI           0
# Year          0
# Month         0
# Day           0
# dtype: int64

# %% [markdown]
# ## Reading and Parsing Weather Data

# %%
weather_data
# Out:
#       Unnamed: 0                      date  temperature_2m_max  \
# 0              0 2015-01-11 00:00:00+00:00              28.209
# 1              1 2015-01-12 00:00:00+00:00              27.709
# 2              2 2015-01-13 00:00:00+00:00              28.159
# 3              3 2015-01-14 00:00:00+00:00              28.959
# 4              4 2015-01-15 00:00:00+00:00              28.209
# ...          ...                       ...                 ...
# 3638        3638 2024-12-27 00:00:00+00:00              30.253
# 3639        3639 2024-12-28 00:00:00+00:00              30.103
# 3640        3640 2024-12-29 00:00:00+00:00              31.003
# 3641        3641 2024-12-30 00:00:00+00:00              31.053
# 3642        3642 2024-12-31 00:00:00+00:00              30.653
#
#       temperature_2m_min  precipitation_sum  weather_code  sunshine_duration  \
# 0                 13.259                0.0           0.0          37052.594
# 1                 12.509                0.0           3.0          37158.527
# 2                 14.859                0.0           3.0          37167.082
# 3                 15.459                0.0           3.0          37175.984
# 4                 14.009                0.0           3.0          37290.023
# ...                  ...                ...           ...                ...
# 3638              20.053                2.3          53.0          31781.553
# 3639              19.503                0.2          51.0          36000.000
# 3640              19.603                0.2          51.0          34506.890
# 3641              19.803                0.0           0.0          36073.367
# 3642              18.903                0.0           0.0          36070.176
#
#       cloud_cover_mean  wind_speed_10m_mean  winddirection_10m_dominant
# 0             0.000000             8.084107                   87.986560
# 1            21.750000             7.937115                   89.543495
# 2            48.250000             6.330598                   58.540066
# 3            43.041668             5.552982                   51.170260
# 4            44.416668             5.279206                   94.532120
# ...                ...                  ...                         ...
# 3638         59.875000             6.546581                  169.180630
# 3639         21.458334             5.255987                  268.085020
# 3640         35.708332             4.277875                   57.926180
# 3641          1.791667             3.847927                   62.987446
# 3642          0.000000             5.049099                   68.921520
#
# [3643 rows x 10 columns]

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3643 entries, 0 to 3642
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  3643 non-null   int64
#  1   date                        3643 non-null   datetime64[ns, UTC]
#  2   temperature_2m_max          3643 non-null   float64
#  3   temperature_2m_min          3643 non-null   float64
#  4   precipitation_sum           3643 non-null   float64
#  5   weather_code                3643 non-null   float64
#  6   sunshine_duration           3643 non-null   float64
#  7   cloud_cover_mean            3643 non-null   float64
#  8   wind_speed_10m_mean         3643 non-null   float64
#  9   winddirection_10m_dominant  3643 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(8), int64(1)
# memory usage: 284.7 KB

# %%
weather_data.describe()
# Out:
#         Unnamed: 0  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# count  3643.000000         3643.000000         3643.000000        3643.000000
# mean   1821.000000           30.922648           20.245362           3.352265
# std    1051.787843            4.040142            3.107583           8.984942
# min       0.000000           20.203000            9.403000           0.000000
# 25%     910.500000           28.003000           18.053000           0.000000
# 50%    1821.000000           29.903000           21.353000           0.000000
# 75%    2731.500000           33.806000           22.603000           2.500000
# max    3642.000000           42.953000           27.653000         174.299990
#
#        weather_code  sunshine_duration  cloud_cover_mean  wind_speed_10m_mean  \
# count   3643.000000        3643.000000       3643.000000          3643.000000
# mean      26.948394       34049.086598         48.265166            10.018777
# std       27.248104       10452.299743         36.094136             4.853772
# min        0.000000           0.000000          0.000000             2.647810
# 25%        2.000000       33882.047000         13.854166             6.257000
# 50%        3.000000       37325.277000         43.541668             8.452968
# 75%       53.000000       39809.224500         84.791668            12.908714
# max       65.000000       43200.000000        100.000000            34.238230
#
#        winddirection_10m_dominant
# count                 3643.000000
# mean                   215.794624
# std                     87.731761
# min                      0.260454
# 25%                    107.119605
# 50%                    256.334200
# 75%                    276.041100
# max                    359.999970

# %%
weather_data.isna().sum()
# Out:
# Unnamed: 0                    0
# date                          0
# temperature_2m_max            0
# temperature_2m_min            0
# precipitation_sum             0
# weather_code                  0
# sunshine_duration             0
# cloud_cover_mean              0
# wind_speed_10m_mean           0
# winddirection_10m_dominant    0
# dtype: int64

# %% [markdown]
# ### Weather data has no missing values

# %% [markdown]
# ## Merging both datasets

# %%
# Normalising date timeones (weather is in UTC)

weather_data["date"] = weather_data["date"].dt.tz_localize(None)
aqi_data["Date"] = aqi_data["Date"].dt.tz_localize(None)

# %%
# Merge both datasets with an inner join

merged = aqi_data.merge(weather_data,
                        left_on = "Date",
                        right_on= "date",
                        how= "inner")

# %%
merged
# Out:
#       Unnamed: 0_x       Date    AQI  Year  Month  Day  Unnamed: 0_y  \
# 0                0 2018-01-01   75.0  2018      1    1          1086
# 1                1 2018-01-02   76.0  2018      1    2          1087
# 2                2 2018-01-03   79.0  2018      1    3          1088
# 3                3 2018-01-04   84.0  2018      1    4          1089
# 4                4 2018-01-05   97.0  2018      1    5          1090
# ...            ...        ...    ...   ...    ...  ...           ...
# 2552          2552 2024-12-27  109.0  2024     12   27          3638
# 2553          2553 2024-12-28   95.0  2024     12   28          3639
# 2554          2554 2024-12-29  110.0  2024     12   29          3640
# 2555          2555 2024-12-30   87.0  2024     12   30          3641
# 2556          2556 2024-12-31  103.0  2024     12   31          3642
#
#            date  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# 0    2018-01-01              28.253              14.503                0.0
# 1    2018-01-02              28.453              12.903                0.0
# 2    2018-01-03              28.903              15.303                0.0
# 3    2018-01-04              28.353              15.303                0.0
# 4    2018-01-05              28.453              14.003                0.0
# ...         ...                 ...                 ...                ...
# 2552 2024-12-27              30.253              20.053                2.3
# 2553 2024-12-28              30.103              19.503                0.2
# 2554 2024-12-29              31.003              19.603                0.2
# 2555 2024-12-30              31.053              19.803                0.0
# 2556 2024-12-31              30.653              18.903                0.0
#
#       weather_code  sunshine_duration  cloud_cover_mean  wind_speed_10m_mean  \
# 0              0.0          36062.707          0.000000             5.679092
# 1              1.0          36040.188          7.166666             4.744073
# 2              0.0          36101.605          0.083333             5.611268
# 3              0.0          36083.652          1.541667             5.784296
# 4              3.0          36066.500         46.125000             5.506170
# ...            ...                ...               ...                  ...
# 2552          53.0          31781.553         59.875000             6.546581
# 2553          51.0          36000.000         21.458334             5.255987
# 2554          51.0          34506.890         35.708332             4.277875
# 2555           0.0          36073.367          1.791667             3.847927
# 2556           0.0          36070.176          0.000000             5.049099
#
#       winddirection_10m_dominant
# 0                     270.613800
# 1                     278.325560
# 2                     285.883900
# 3                     326.564940
# 4                     287.776520
# ...                          ...
# 2552                  169.180630
# 2553                  268.085020
# 2554                   57.926180
# 2555                   62.987446
# 2556                   68.921520
#
# [2557 rows x 16 columns]

# %%
# Dropping unnecessary columns

merged = merged.drop(columns=["Unnamed: 0_x", "Unnamed: 0_y", "date"])

# %%
# Set Date as Index
merged.set_index("Date", inplace=True)

# %%
merged
# Out:
#               AQI  Year  Month  Day  temperature_2m_max  temperature_2m_min  \
# Date
# 2018-01-01   75.0  2018      1    1              28.253              14.503
# 2018-01-02   76.0  2018      1    2              28.453              12.903
# 2018-01-03   79.0  2018      1    3              28.903              15.303
# 2018-01-04   84.0  2018      1    4              28.353              15.303
# 2018-01-05   97.0  2018      1    5              28.453              14.003
# ...           ...   ...    ...  ...                 ...                 ...
# 2024-12-27  109.0  2024     12   27              30.253              20.053
# 2024-12-28   95.0  2024     12   28              30.103              19.503
# 2024-12-29  110.0  2024     12   29              31.003              19.603
# 2024-12-30   87.0  2024     12   30              31.053              19.803
# 2024-12-31  103.0  2024     12   31              30.653              18.903
#
#             precipitation_sum  weather_code  sunshine_duration  \
# Date
# 2018-01-01                0.0           0.0          36062.707
# 2018-01-02                0.0           1.0          36040.188
# 2018-01-03                0.0           0.0          36101.605
# 2018-01-04                0.0           0.0          36083.652
# 2018-01-05                0.0           3.0          36066.500
# ...                       ...           ...                ...
# 2024-12-27                2.3          53.0          31781.553
# 2024-12-28                0.2          51.0          36000.000
# 2024-12-29                0.2          51.0          34506.890
# 2024-12-30                0.0           0.0          36073.367
# 2024-12-31                0.0           0.0          36070.176
#
#             cloud_cover_mean  wind_speed_10m_mean  winddirection_10m_dominant
# Date
# 2018-01-01          0.000000             5.679092                  270.613800
# 2018-01-02          7.166666             4.744073                  278.325560
# 2018-01-03          0.083333             5.611268                  285.883900
# 2018-01-04          1.541667             5.784296                  326.564940
# 2018-01-05         46.125000             5.506170                  287.776520
# ...                      ...                  ...                         ...
# 2024-12-27         59.875000             6.546581                  169.180630
# 2024-12-28         21.458334             5.255987                  268.085020
# 2024-12-29         35.708332             4.277875                   57.926180
# 2024-12-30          1.791667             3.847927                   62.987446
# 2024-12-31          0.000000             5.049099                   68.921520
#
# [2557 rows x 12 columns]

# %%
# Export Merged Dataset
merged.to_csv("../data/processed/processed.csv")
